# %% [markdown]
# Data analysis, using random forests

# %%
import matplotlib.pyplot as plt
import os
import csv
import numpy as np
import pandas as pd
import sklearn as sk
from functions import * #importo tutte le funzioni da functions.py

# %% [markdown]
# prendiamo i dati e li normalizziamo:

# %%
files = ["S1_bkg_mapA_11x11.csv", "S1_mapA_11x11.csv"]#["S2_bkg_mapA_11x11.csv", "S2_mapA_11x11.csv"]
directory= "/home/luca/Uni/VI/Data science/Progetto/prog_DS/data_csv/"
names = [directory+n for n in files]
dir_save= "/home/luca/Uni/VI/Data science/Progetto/prog_DS/data_norm_csv/"
name_save =[dir_save+n.removesuffix('.csv') + "_norm.csv" for n in files]
k = 0
for name in names:
    data = pd.read_csv(name)
    with open(name_save[k], "w", newline="") as file:
        writer = csv.writer(file)
        #writer.writerow(["riga","colonna", "x", "y"])  # intestazione
        for i in range(11):
            for j in range(11):
                filtro = data[(data['riga'] == i) & (data['colonna'] == j) & (data['x'] <= 1500)]
                norm_y = (filtro['y'].values-filtro['y'].values.mean())/filtro['y'].values.std()
                new_data = pd.DataFrame({'x': filtro['x'].values, 'y': norm_y})
                for xi, yi in zip(new_data.x, new_data.y):
                    #writer.writerow([i,j, xi, yi])
    k += 1

directory= "/home/luca/Uni/VI/Data science/Progetto/prog_DS/data_csv/minerali.csv"
out = "/home/luca/Uni/VI/Data science/Progetto/prog_DS/data_norm_csv/minerali_norm.csv"
data = pd.read_csv(directory)
minerali = data['nome'].unique()
with open(out, "w", newline="") as file:
    writer = csv.writer(file)
    #writer.writerow(["nome", "x", "y"])  # intestazione
    for minerale in minerali:
        filtro = data[(data['nome'] == minerale)]
        norm_y = (filtro['y'].values-filtro['y'].values.mean())/filtro['y'].values.std()
        new_data = pd.DataFrame({'x': filtro['x'].values, 'y': norm_y})
        for xi, yi in zip(new_data.x, new_data.y):
            #writer.writerow([minerale, xi, yi])

# %%
dir_save= "/home/luca/Uni/VI/Data science/Progetto/prog_DS/data_norm_csv/"
files = ["S2_bkg_mapA_11x11.csv", "S2_mapA_11x11.csv"]#["S1_bkg_mapA_11x11.csv", "S1_mapA_11x11.csv"]
name_save =[dir_save+n.removesuffix('.csv') + "_norm.csv" for n in files]

plot_unknown_minerals(name_save,[0],[0]) #plotto la prima colonna e la prima riga di ogni csv
plot_unknown_minerals(name_save,[0],[1]) #plotto la prima colonna

# %% [markdown]
# quale è il max della x nei miei valori tabulati?

# %%
directory= "/home/luca/Uni/VI/Data science/Progetto/prog_DS/data_csv/minerali.csv"
data = pd.read_csv(directory)
minerali = data['nome'].unique()
for minerale in minerali:
    filtro = data[(data['nome'] == minerale)]
    print(filtro['x'].values.max())
# Out:
# 1500.0
# 1500.0
# 1500.0
# 1500.0
# 1500.0
# 1500.0
# 1500.0
# 1500.0
# 1500.0
# 1500.0
# 1500.0
# 1500.0
# 1500.0
# 1500.0
# 1500.0
# 1500.0
# 1500.0
# 1500.0
# 1500.0
# 1500.0
# 1500.0
# 1500.0
# 1500.0
# 1500.0
# 1500.0
# 1500.0
# 1500.0
# 1500.0
# 1500.0
# 1500.0
# 1500.0
# 1500.0
# 1500.0
# 1500.0
# 1500.0
# 1500.0
# 1500.0
# 1500.0
# 1500.0
# 1500.0
# 1500.0
# 1500.0
# 1500.0
# 1500.0
# 1500.0
# 1500.0
# 1500.0
# 1500.0
# 1500.0
# 1500.0
# 1500.0
# 1500.0
# 1500.0
# 1500.0
# 1500.0
# 1500.0
# 1500.0
# 1500.0
# 1500.0
# 1500.0
# 1500.0

# %% [markdown]
# 1500

# %% [markdown]
# Esempio di plot cazzuto

# %%
fig, ax = plt.subplots(figsize=(12, 6))
dir_save= "/home/luca/Uni/VI/Data science/Progetto/prog_DS/data_norm_csv/"
files = ["S2_bkg_mapA_11x11.csv", "S2_mapA_11x11.csv"]#["S1_bkg_mapA_11x11.csv", "S1_mapA_11x11.csv"]
name_save =[dir_save+n.removesuffix('.csv') + "_norm.csv" for n in files]
plot_unknown_minerals(name_save,[0],[0],ax) #plotto la prima colonna e la prima riga di ogni csv

plot_minerale([0],ax)
